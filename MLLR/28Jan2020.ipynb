# %%
install.packages('ISLR')
library(ISLR)
# Out:
# Warning message:
# "package 'ISLR' is in use and will not be installed"

# %%
#Auto = read.csv('Auto.csv',header=T,na.strings="?")
# Auto = na.omit(Auto)
# summary(Auto)

CarSeats = read.csv('carseat.csv',header=T,na.strings=",")
summary(CarSeats)
pairs(CarSeats)
# Out:
#      Sales          CompPrice       Income        Advertising
#  Min.   : 0.000   Min.   : 77   Min.   : 21.00   Min.   : 0.000
#  1st Qu.: 5.390   1st Qu.:115   1st Qu.: 42.75   1st Qu.: 0.000
#  Median : 7.490   Median :125   Median : 69.00   Median : 5.000
#  Mean   : 7.496   Mean   :125   Mean   : 68.66   Mean   : 6.635
#  3rd Qu.: 9.320   3rd Qu.:135   3rd Qu.: 91.00   3rd Qu.:12.000
#  Max.   :16.270   Max.   :175   Max.   :120.00   Max.   :29.000
#    Population        Price        ShelveLoc        Age          Education
#  Min.   : 10.0   Min.   : 24.0   Bad   : 96   Min.   :25.00   Min.   :10.0
#  1st Qu.:139.0   1st Qu.:100.0   Good  : 85   1st Qu.:39.75   1st Qu.:12.0
#  Median :272.0   Median :117.0   Medium:219   Median :54.50   Median :14.0
#  Mean   :264.8   Mean   :115.8                Mean   :53.32   Mean   :13.9
#  3rd Qu.:398.5   3rd Qu.:131.0                3rd Qu.:66.00   3rd Qu.:16.0
#  Max.   :509.0   Max.   :191.0                Max.   :80.00   Max.   :18.0
# ...

# %%
# lm.fit <- lm(mpg~horsepower,data =Auto)
lm.fit <- lm(Sales~Income,data=CarSeats)
summary(lm.fit)
# Out:
# Call:
# lm(formula = Sales ~ Income, data = CarSeats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.2629 -1.9447 -0.1772  1.7654  8.9064
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.44356    0.37061  17.386  < 2e-16 ***
# Income       0.01533    0.00500   3.067  0.00231 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.795 on 398 degrees of freedom
# Multiple R-squared:  0.02309,	Adjusted R-squared:  0.02063
# F-statistic: 9.407 on 1 and 398 DF,  p-value: 0.00231

# %%
floor(summary(lm.fit)$r.sq*100)
# Out:
# [1] 2

# %%
predict(lm.fit,data.frame(Income=c(21)),interval="confidence")
# Out:
#   fit      lwr      upr
# 1 6.765563 6.222531 7.308595

# %%
plot(Auto[["horsepower"]],Auto[["mpg"]],xlab="horsepower",ylab="mpg")
abline(coef(lm.fit),col="red")
abline(mean(Auto[["mpg"]]),0,col="green")
legend("right",legend=c("Model", "Mean"),col=c("red", "green"),lwd=1)
# Out:
# Error in plot(Auto[["horsepower"]], Auto[["mpg"]], xlab = "horsepower", : object 'Auto' not found
# Traceback:
#
# 1. plot(Auto[["horsepower"]], Auto[["mpg"]], xlab = "horsepower",
#  .     ylab = "mpg")

# %%
x=c(1:100);
y=exp(0.1*x);
cor(x,y,method="pearson");
cor(x,y,method="spearman");
# Out:
# [1] 0.6931107
# [1] 1

# %%
plot(x,y)
# Out:
# plot without title

# %%
pairs(Auto)
# Out:
# plot without title

# %%
cor(subset(Auto,select=-name))
# Out:
#              mpg        cylinders  displacement horsepower weight
# mpg           1.0000000 -0.7776175 -0.8051269   -0.7784268 -0.8322442
# cylinders    -0.7776175  1.0000000  0.9508233    0.8429834  0.8975273
# displacement -0.8051269  0.9508233  1.0000000    0.8972570  0.9329944
# horsepower   -0.7784268  0.8429834  0.8972570    1.0000000  0.8645377
# weight       -0.8322442  0.8975273  0.9329944    0.8645377  1.0000000
# acceleration  0.4233285 -0.5046834 -0.5438005   -0.6891955 -0.4168392
# year          0.5805410 -0.3456474 -0.3698552   -0.4163615 -0.3091199
# origin        0.5652088 -0.5689316 -0.6145351   -0.4551715 -0.5850054
#              acceleration year       origin
# mpg           0.4233285    0.5805410  0.5652088
# cylinders    -0.5046834   -0.3456474 -0.5689316
# displacement -0.5438005   -0.3698552 -0.6145351
# horsepower   -0.6891955   -0.4163615 -0.4551715
# weight       -0.4168392   -0.3091199 -0.5850054
# acceleration  1.0000000    0.2903161  0.2127458
# ...

# %%
cor(subset(Auto,select=-name),method="spearman")
# Out:
#              mpg        cylinders  displacement horsepower weight
# mpg           1.0000000 -0.8231746 -0.8552336   -0.8536164 -0.8755851
# cylinders    -0.8231746  1.0000000  0.9135663    0.8161885  0.8759718
# displacement -0.8552336  0.9135663  1.0000000    0.8761708  0.9456304
# horsepower   -0.8536164  0.8161885  0.8761708    1.0000000  0.8788193
# weight       -0.8755851  0.8759718  0.9456304    0.8788193  1.0000000
# acceleration  0.4415389 -0.4762660 -0.4994034   -0.6581423 -0.4051087
# year          0.5748409 -0.3310874 -0.3065821   -0.3894983 -0.2809807
# origin        0.5804824 -0.6104676 -0.7095729   -0.5089885 -0.6313708
#              acceleration year       origin
# mpg           0.4415389    0.5748409  0.5804824
# cylinders    -0.4762660   -0.3310874 -0.6104676
# displacement -0.4994034   -0.3065821 -0.7095729
# horsepower   -0.6581423   -0.3894983 -0.5089885
# weight       -0.4051087   -0.2809807 -0.6313708
# acceleration  1.0000000    0.2783064  0.2274064
# ...

# %%
cor(Auto[["horsepower"]],Auto[["mpg"]],method="spearman")
# Out:
# [1] -0.8536164

# %%
cor(Auto[["horsepower"]],Auto[["mpg"]])
# Out:
# [1] -0.7784268
